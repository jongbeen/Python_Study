# %% [markdown]
# ## 목차
#
# ### 1. 인터프리터에서 마지막 값을 사용하고 싶을 때
# ### 2. 값을 무시하고 싶을 때
# ### 3. 변수나 함수명에 특별한 의미를 부여하고 싶을 때
# ### 4. 숫자 리터럴 값의 자릿수 구분을 위한 구분자로써 사용할 때

# %% [markdown]
# ### 1. 인터프리터에서 저장한 마지막 값을 사용할 때
# ![image.png](attachment:image.png)

# %%
10
# Out:
# 10

# %%
_*3
# Out:
# 30

# %% [markdown]
# ### 2. 값을 무시하고 싶을 때

# %% [markdown]
# ![image.png](attachment:image.png)
